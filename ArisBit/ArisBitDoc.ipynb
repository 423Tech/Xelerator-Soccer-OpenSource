# %% [markdown]
# ## ArisBit v1.0 使用手册

# %% [markdown]
# #### 导入库

# %%
from arisbit import ArisBit

# %% [markdown]
# #### 实例化对象

# %%
Bot = ArisBit()

# %% [markdown]
# #### 设置电机转速

# %% [markdown]
# ##### 范围应当在[-1000,1000]之间

# %%
Bot.SetMotor(123, 234, 345, 456)

# %% [markdown]
# #### 设置电机倍率

# %% [markdown]
# ##### 由于下位机使用PPS作为PID计算标准，使用本方法将最小转速、最大转速归一化到[-1000,1000]

# %%
Bot.SetMotorRatio(14)

# %% [markdown]
# #### 获取偏航角（指南针）

# %%
Bot.GetYaw()

# %% [markdown]
# #### 获取电池电压

# %%
Bot.GetBatteryVoltage()
# Out:
# 运行具有“Python 3.9.6”的单元格需要ipykernel包。
#
# 使用所需的包 <a href='command:jupyter.createPythonEnvAndSelectController'>创建 Python 环境</a>。
#
# 或使用命令“/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall”安装“ipykernel”

# %% [markdown]
# #### 设置IO高低电平

# %%
Bot.SetIO(1,1)

# %% [markdown]
# #### 获取按钮按下状态

# %%
Bot.GetKeyStatus()
